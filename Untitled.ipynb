# %%
import pandas as pd

# %%
df = pd.read_json('job_news.json')

# %%
df.iloc[[1,5,7,93,34]]
# Out:
#                                      _id         source        crawled_time  \
# 1   {'$oid': '607126699e9fa8866d7cefcd'}  vieclam24h.vn 2021-10-04 11:15:37
# 5   {'$oid': '6071266a9e9fa8866d7cefd1'}  vieclam24h.vn 2021-10-04 11:15:38
# 7   {'$oid': '6071266a9e9fa8866d7cefd3'}  vieclam24h.vn 2021-10-04 11:15:38
# 93  {'$oid': '6071267b9e9fa8866d7cf029'}  vieclam24h.vn 2021-10-04 11:15:55
# 34  {'$oid': '6071266e9e9fa8866d7cefee'}  vieclam24h.vn 2021-10-04 11:15:42
#
#                                             news_link  \
# 1   https://vieclam24h.vn/quan-tri-kinh-doanh/giam...
# 5   https://vieclam24h.vn/tu-van/newstarland-nhan-...
# 7   https://vieclam24h.vn/hoa-hoc-sinh-hoc/pho-pho...
# 93  https://vieclam24h.vn/hoa-hoc-sinh-hoc/ky-su-h...
# 34  https://vieclam24h.vn/dien-dien-tu-dien-lanh/n...
#
#                                                 title         salary  \
# 1   Giám Sát Trung Tâm Games Tại Hà Nội Và Hồ Chí ...   7 - 10 triệu
# ...

# %%
df
# Out:
#                                        _id            source  \
# 0     {'$oid': '607126699e9fa8866d7cefcc'}     vieclam24h.vn
# 1     {'$oid': '607126699e9fa8866d7cefcd'}     vieclam24h.vn
# 2     {'$oid': '607126699e9fa8866d7cefce'}     vieclam24h.vn
# 3     {'$oid': '6071266a9e9fa8866d7cefcf'}     vieclam24h.vn
# 4     {'$oid': '6071266a9e9fa8866d7cefd0'}     vieclam24h.vn
# ...                                    ...               ...
# 7457  {'$oid': '6071d6a88e3c10fa5b1587d9'}  timviecnhanh.com
# 7458  {'$oid': '6071d6a88e3c10fa5b1587da'}  timviecnhanh.com
# 7459  {'$oid': '6071d6a88e3c10fa5b1587db'}  timviecnhanh.com
# 7460  {'$oid': '6071d6a88e3c10fa5b1587dc'}  timviecnhanh.com
# 7461  {'$oid': '6071d6a88e3c10fa5b1587dd'}  timviecnhanh.com
#
#             crawled_time                                          news_link  \
# 0    2021-10-04 11:15:36  https://vieclam24h.vn/dien-dien-tu-dien-lanh/n...
# 1    2021-10-04 11:15:37  https://vieclam24h.vn/quan-tri-kinh-doanh/giam...
# ...
