# %%
import pandas as pd

# %%
df0 = pd.read_json('job_news.json')

# %%
df0.head()
# Out:
#                                     _id         source        crawled_time  \
# 0  {'$oid': '607126699e9fa8866d7cefcc'}  vieclam24h.vn 2021-10-04 11:15:36
# 1  {'$oid': '607126699e9fa8866d7cefcd'}  vieclam24h.vn 2021-10-04 11:15:37
# 2  {'$oid': '607126699e9fa8866d7cefce'}  vieclam24h.vn 2021-10-04 11:15:37
# 3  {'$oid': '6071266a9e9fa8866d7cefcf'}  vieclam24h.vn 2021-10-04 11:15:37
# 4  {'$oid': '6071266a9e9fa8866d7cefd0'}  vieclam24h.vn 2021-10-04 11:15:38
#
#                                            news_link  \
# 0  https://vieclam24h.vn/dien-dien-tu-dien-lanh/n...
# 1  https://vieclam24h.vn/quan-tri-kinh-doanh/giam...
# 2  https://vieclam24h.vn/ban-hang/nhan-vien-tu-va...
# 3  https://vieclam24h.vn/dien-dien-tu-dien-lanh/n...
# 4  https://vieclam24h.vn/nhan-vien-kinh-doanh/nha...
#
#                                                title         salary  \
# 0                Nhân Viên Bảo Trì Điện - Bình Dương   7 - 10 triệu
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7462 entries, 0 to 7461
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               7462 non-null   object
#  1   source            7462 non-null   object
#  2   crawled_time      7462 non-null   datetime64[ns]
#  3   news_link         7462 non-null   object
#  4   title             7462 non-null   object
#  5   salary            7462 non-null   object
#  6   number_available  7462 non-null   object
#  7   description       7408 non-null   object
#  8   benefits          7392 non-null   object
#  9   working_location  7462 non-null   object
#  10  position          6462 non-null   object
#  11  types             7462 non-null   object
#  12  experience        7462 non-null   object
#  13  degree            7462 non-null   object
#  14  gender            7462 non-null   object
#  15  updated_date      7462 non-null   object
# ...

# %% [markdown]
# # Loại bỏ trùng lặp

# %%
import recordlinkage

# %%
df0_indexer = recordlinkage.Index()
df0_indexer.sortedneighbourhood(left_on='working_location')
